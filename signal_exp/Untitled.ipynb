# %%
import numpy as np
from scipy import fftpack
import matplotlib.pyplot as plt

# %%
sampling_rate = 250
t = np.arange(0,1,1/sampling_rate)
y = np.sin(2*np.pi*10*t)+np.sin(2*np.pi*9*t)+np.sin(2*np.pi*8*t)+np.random.randn(t.size)
f = fftpack.fft(y)
print(f.size)
# Out:
# 250

# %%
plt.plot(f)
# Out:
# C:\Users\West\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
y_again = fftpack.ifft(c)
print(y_again)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23300/2854019469.py in <module>
# ----> 1 y_again = fftpack.ifft(c)
#       2 print(y_again)
#
# NameError: name 'c' is not defined

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])
